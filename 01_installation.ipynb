# %% [markdown]
# # steps
# 1. create a new conda environment 'python_ml'
# 2. install the following packages:
#     1. python conda install python
#         1. pandas
#         2. numpy
#         3. matplotlib
#         4. seaborn
#         5. scipy
#         6. scikit-learn
#         7. jupyter
#         8. openpyxl
#         9. plotly
#
#
#  pip install pandas numpy matplotlib seaborn scipy sickit-learn jupyter openpyxl plotly
