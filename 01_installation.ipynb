# %% [markdown]
# # steps:
# 1. Create a new conda environment 'pyhton_ML'
# 2. install the following packages
#     1. pyhton conda install python
#         1. pandas
#         2. numpy
#         3. matplotlib
#         4. seaborn
#         5. scipy
#         6. sickit_learn
#         7. jupyter
#         8. openpyxl
#         9. plotly
#
#     # pip install ......
